# %% [markdown]
# # Data Science Tools And Ecosystem

# %% [markdown]
# In This Notebook Data Science Tools Are Summarized

# %% [markdown]
# Some of popular Languages Data Science use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some Popular data science libraries are:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# | Data Science Tools |
# | :--- |
# | Jupyter Notebook |
# | RStudio |
# | VS Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to mutiply then add integers.
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60.
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
# * List popular languages for Data Science
# * Identify commonly used libraries in Data Science
# * Practice evaluating basic arithmetic expressions in Python

# %% [markdown]
# ## Author
# Faseeh Ur Rehman
